# %% [markdown]
# # Capstone Project Group 1
# ## Analysis of the Economic Impact of Tourism in Southeast Asia

# %%
#packages to work with

import pandas as pd
#import psycopg2
#import sql_functions as sf    #postgres SQL
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import scipy as stat
#import sqlalchemy
import chardet

#import also any other own custom functions packages if needed
#copy our custom functions(sql_functions) file in this repository so that there is an access to the main functions there
#(upload it on main so that the others can pull it)

# %%
# Import requests package
import requests

# %%
# Set URL as url
#url = ''

# %%
# To be able to pull the API key from the .env, we need to import and run the load_dotenv function from the dotenv module first.
#from dotenv import load_dotenv
#load_dotenv()

# %%
#read excel data into pandas DataFrame

#pd.read_excel()

# %%
#read in your csv data into pandas DataFrame

asean_visitors = pd.read_csv('data/pivot.csv', header=1)

# %%
asean_visitors.head(1)
# Out:
#   Destination Country         Origin Country 1995 1996     1997     1998  \
# 0   Brunei Darussalam  Total Country (World)  NaN  NaN  643 215  964 080
#
#       1999     2000     2001     2002  ...       2013       2014     2015  \
# 0  954 907  984 093  840 272  890 688  ...  3 279 160  3 885 537  218 213
#
#       2016     2017     2018     2019    2020   2021    2022
# 0  218 809  258 955  278 136  333 244  62 325  3 543  35 701
#
# [1 rows x 30 columns]

# %%
asean_visitors['avg_visitors'] = asean_visitors.mean(numeric_only=True, axis=1).astype(float)

# %%
asean_visitors.loc[:, '1995':'2022'] = asean_visitors.loc[:, '1995':'2022'].replace(' ','', regex=True)

# %%
asean_visitors.loc[:, 'Destination Country':'Origin Country'] = asean_visitors.loc[:, 'Destination Country':'Origin Country'].lower().replace(' ','_')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/kt/c_d917yx6vs3yh3pfv_r5dyc0000gn/T/ipykernel_65232/688542590.py in ?()
# ----> 1 asean_visitors.loc[:, 'Destination Country':'Origin Country'] = asean_visitors.loc[:, 'Destination Country':'Origin Country'].lower().replace(' ','_')
#
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'lower'

# %%
employment_ocup = pd.read_excel('data/Number of Employment in ASEAN by Occupation .xlsx')

# %%
employment_ocup.set_index('Occupation', inplace=True)

# %%
employment_ocup1 = employment_ocup.transpose()

# %%
employment_ocup1.head(1)
# Out:
# Occupation                 Professionals, technical and related workers  \
# Brunei Darussalam\n(2022)                                        57.849
#
# Occupation                 Administrative, executive and managerial workers  \
# Brunei Darussalam\n(2022)                                            16.881
#
# Occupation                 Clerical and related workers  \
# Brunei Darussalam\n(2022)                        21.366
#
# Occupation                 Services and sales workers  \
# Brunei Darussalam\n(2022)                      47.528
#
# Occupation                 Agricultural, animal husbandry and forestry workers; fishermen and hunters  \
# Brunei Darussalam\n(2022)                                              2.735
#
# Occupation                 Production and related workers, transport equipment operators and labourers  \
# Brunei Darussalam\n(2022)                                             28.657
#
# Occupation                 Others    Total
# ...

# %%
gdp_data = pd.read_csv('data/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_39.csv')

# %%
gdp_data.columns.str.lower()
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 2                    Afghanistan          AFG  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  GDP (current US$)
# 262                  Yemen, Rep.          YEM  GDP (current US$)
# 263                 South Africa          ZAF  GDP (current US$)
# 264                       Zambia          ZMB  GDP (current US$)
# 265                     Zimbabwe          ZWE  GDP (current US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# ...

# %%
gdp_data.reset_index('Country Code', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 gdp_data.reset_index('Country Code ', inplace=True)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/frame.py:6176, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6174 if not isinstance(level, (tuple, list)):
#    6175     level = [level]
# -> 6176 level = [self.index._get_level_number(lev) for lev in level]
#    6177 if len(level) < self.index.nlevels:
#    6178     new_index = self.index.droplevel(level)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/frame.py:6176, in <listcomp>(.0)
#    6174 if not isinstance(level, (tuple, list)):
#    6175     level = [level]
# -> 6176 level = [self.index._get_level_number(lev) for lev in level]
# ...

# %%
#switch columns and rows
# return the transpose 
#result = df.transpose() 
  
# Print the result 
#print(result)
