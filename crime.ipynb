# %%
import pandas as pd
crime = pd.read_csv('data/SPD_Crime_Data__2008-Present_20240704.csv')

# %%
crime.head()
# Out:
#   Report Number   Offense ID  Offense Start DateTime    Offense End DateTime  \
# 0   2020-044620  12605873663  02/05/2020 10:10:00 AM                     NaN
# 1   2020-044452  12605598696  02/03/2020 08:00:00 AM  02/04/2020 08:00:00 AM
# 2   2020-044465  12605567653  02/02/2020 08:30:00 PM  02/02/2020 09:30:00 PM
# 3   2020-044225  12605174036  02/05/2020 01:17:00 AM  02/05/2020 02:21:00 AM
# 4   2020-044076  12605081469  02/05/2020 12:51:21 AM                     NaN
#
#           Report DateTime Group A B Crime Against Category  \
# 0  02/05/2020 11:24:31 AM         A                SOCIETY
# 1  02/05/2020 10:06:28 AM         A               PROPERTY
# 2  02/05/2020 09:39:33 AM         A               PROPERTY
# 3  02/05/2020 03:30:55 AM         A               PROPERTY
# 4  02/05/2020 12:51:31 AM         B                SOCIETY
#
#                        Offense Parent Group  \
# 0                    DRUG/NARCOTIC OFFENSES
# 1                             LARCENY-THEFT
# ...

# %%
crime['MCPP'].dropna()
# Out:
# 0                     MAGNOLIA
# 1            ROOSEVELT/RAVENNA
# 2            ROOSEVELT/RAVENNA
# 3                     MAGNOLIA
# 4                BALLARD SOUTH
#                   ...
# 1128967           PIGEON POINT
# 1128968             QUEEN ANNE
# 1128969      ROOSEVELT/RAVENNA
# 1128970    DOWNTOWN COMMERCIAL
# 1128971             QUEEN ANNE
# Name: MCPP, Length: 1128945, dtype: object

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1128972 entries, 0 to 1128971
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   Report Number           1128972 non-null  object
#  1   Offense ID              1128972 non-null  int64
#  2   Offense Start DateTime  1127162 non-null  object
#  3   Offense End DateTime    647977 non-null   object
#  4   Report DateTime         1128972 non-null  object
#  5   Group A B               1128972 non-null  object
#  6   Crime Against Category  1128972 non-null  object
#  7   Offense Parent Group    1128972 non-null  object
#  8   Offense                 1128972 non-null  object
#  9   Offense Code            1128972 non-null  object
#  10  Precinct                1128965 non-null  object
#  11  Sector                  1128965 non-null  object
#  12  Beat                    1128965 non-null  object
# ...

# %%
crime.isnull().sum()
# Out:
# Report Number                  0
# Offense ID                     0
# Offense Start DateTime      1810
# Offense End DateTime      480995
# Report DateTime                0
# Group A B                      0
# Crime Against Category         0
# Offense Parent Group           0
# Offense                        0
# Offense Code                   0
# Precinct                       7
# Sector                         7
# Beat                           7
# MCPP                          27
# 100 Block Address          50283
# Longitude                      0
# Latitude                       0
# dtype: int64

# %%
medien = pd.read_csv('data/B24021_median_earnings_occupation_5YALL_-688641291965021816.csv')

# %%
medien
# Out:
#       OBJECTID        GEOID                                    Tract Name  \
# 0            1  53033000300                                Census Tract 3
# 1            2  53033000402                             Census Tract 4.02
# 2            3  53033000500                                Census Tract 5
# 3            4  53033000700                                Census Tract 7
# 4            5  53033000800                                Census Tract 8
# ...        ...          ...                                           ...
# 2271      2272  53033032703  Census Tract 327.03; King County; Washington
# 2272      2273  53033032704  Census Tract 327.04; King County; Washington
# 2273      2274  53033032705  Census Tract 327.05; King County; Washington
# 2274      2275  53033032706  Census Tract 327.06; King County; Washington
# 2275      2276  53033032800     Census Tract 328; King County; Washington
#
# ...

# %%
medien.info()
# we will investigate the ranking per earnings, which job makes the most.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2276 entries, 0 to 2275
# Data columns (total 82 columns):
#  #   Column                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                         --------------  -----
#  0   OBJECTID                                                                                                                       2276 non-null   int64
#  1   GEOID                                                                                                                          2276 non-null   int64
#  2   Tract Name                                                                                                                     2276 non-null   object
# ...

# %%
medien.isnull().sum()
# Out:
# OBJECTID                                                                                                                           0
# GEOID                                                                                                                              0
# Tract Name                                                                                                                         0
# Median Earnings of Total Full-Time Year-Round Civilian Employed Population 16 Years and Over with Earnings                         0
# Median Earnings of Total Full-Time Year-Round Civilian Employed Population 16 Years and Over with Earnings - Margin of Error       0
#                                                                                                                                 ...
# Community Reporting Area ID                                                                                                     1481
# ...

# %%
complaints = pd.read_csv('data/Code_Complaints_and_Violations_20240704.csv')

# %%
complaints.head()
# Out:
#      RecordNum RecordType RecordTypeMapped   RecordTypeDesc  \
# 0  001001-03CP  Complaint          Request     Construction
# 1  001002-03CP  Complaint          Request     Construction
# 2  001003-03CP  Complaint          Request  Vacant Building
# 3  001004-03CP  Complaint          Request         Land Use
# 4  001005-03CP  Complaint          Request         Land Use
#
#                                          Description    OpenDate  \
# 0  Elevator gets stuck at least 3 times a week, f...  2003-11-10
# 1  Concerned about RV pumpout that is currently b...  2003-11-10
# 2  The vacant red apple building and adjacent bui...  2003-11-10
# 3  Trailor and camper parked in back yard.  Peopl...  2003-11-10
# 4  Illegal use of property."Hawkers" or vendors (...  2003-11-10
#
#                         LastInspDate LastInspResult StatusCurrent  \
# 0  POINT (-122.33582172 47.60642293)      Completed     Completed
# 1  POINT (-122.35191884 47.68639169)      Completed     Completed
# ...

# %%
complaints['OpenDate'] = pd.to_datetime(complaints['OpenDate'])

# Define the date range
start_date = '2015-01-01'
end_date = '2017-12-31'

# Filter the DataFrame to get data within the specified date range
filtered_complaints_df = complaints[
    (complaints['OpenDate'] >= start_date) & (complaints['OpenDate'] <= end_date)]

# %%
filtered_complaints_df #MCPP impleament
# Out:
#           RecordNum           RecordType RecordTypeMapped   RecordTypeDesc  \
# 31889   001001-15CP            Complaint          Request         Land Use
# 31890   001002-15CP            Complaint          Request        Emergency
# 31891   001003-15CP            Complaint          Request         Land Use
# 31892   001004-15CP            Complaint          Request         Land Use
# 31893   001005-15CP            Complaint          Request              NaN
# ...             ...                  ...              ...              ...
# 140802   1042108-CT             Citation             Case         Land Use
# 140803   1042109-VI  Notice of Violation             Case  LandLord/Tenant
# 140804   1042110-CT             Citation             Case         Land Use
# 140805   1042111-VI  Notice of Violation             Case              NaN
# 189993  010588-23CP            Complaint          Request  LandLord/Tenant
#
# ...

# %%
complaints.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207388 entries, 0 to 207387
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   RecordNum         207388 non-null  object
#  1   RecordType        207388 non-null  object
#  2   RecordTypeMapped  207388 non-null  object
#  3   RecordTypeDesc    178034 non-null  object
#  4   Description       202842 non-null  object
#  5   OpenDate          207388 non-null  object
#  6   LastInspDate      204293 non-null  object
#  7   LastInspResult    131902 non-null  object
#  8   StatusCurrent     207388 non-null  object
#  9   OriginalAddress1  206166 non-null  object
#  10  OriginalCity      196699 non-null  object
#  11  OriginalState     197323 non-null  object
#  12  OriginalZip       190665 non-null  float64
#  13  Link              207388 non-null  object
#  14  Latitude          204293 non-null  float64
#  15  Longitude         204293 non-null  float64
# ...

# %%
complaints.isnull().sum()
# Out:
# RecordNum               0
# RecordType              0
# RecordTypeMapped        0
# RecordTypeDesc      29354
# Description          4546
# OpenDate                0
# LastInspDate         3095
# LastInspResult      75486
# StatusCurrent           0
# OriginalAddress1     1222
# OriginalCity        10689
# OriginalState       10065
# OriginalZip         16723
# Link                    0
# Latitude             3095
# Longitude            3095
# Location1            3095
# dtype: int64

# %%
life = pd.read_csv('data/Public_Life_Data_-_People_Moving_20240704.csv')

# %%
life
# Out:
#       unique_moving_id               study_id location_id  \
# 0                    1  2018_Seattle_Citywide        MAP1
# 1                    2  2018_Seattle_Citywide        MAP1
# 2                    3  2018_Seattle_Citywide        MAP1
# 3                    4  2018_Seattle_Citywide        MAP1
# 4                    5  2018_Seattle_Citywide        MAP1
# ...                ...                    ...         ...
# 2373              2374       2022_Ballard_Ave        BAL5
# 2374              2375       2022_Ballard_Ave        BAL6
# 2375              2376       2022_Ballard_Ave        BAL6
# 2376              2377       2022_Ballard_Ave        BAL6
# 2377              2378       2022_Ballard_Ave        BAL6
#
#            moving_time_start         moving_time_end moving_day_of_week  \
# 0     08/02/2018 08:01:00 AM  08/02/2018 08:11:00 AM            Weekday
# 1     08/02/2018 08:11:00 AM  08/02/2018 08:21:00 AM            Weekday
# ...

# %%
life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2378 entries, 0 to 2377
# Data columns (total 43 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   unique_moving_id                     2378 non-null   int64
#  1   study_id                             2378 non-null   object
#  2   location_id                          2378 non-null   object
#  3   moving_time_start                    2378 non-null   object
#  4   moving_time_end                      2378 non-null   object
#  5   moving_day_of_week                   2378 non-null   object
#  6   moving_time_of_day                   2378 non-null   object
#  7   moving_count_surveyor                2378 non-null   object
#  8   moving_conditions                    190 non-null    object
#  9   moving_microclimate                  1796 non-null   object
#  10  moving_temperature                   1792 non-null   float64
# ...

# %%
pd.read_csv('data/Food_Establishment_Inspection_Data_20240704.csv')
# Out:
# /var/folders/gj/yd8_00qn1zd25sf7_qyvkdmc0000gp/T/ipykernel_4872/707904068.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('data/Food_Establishment_Inspection_Data_20240704.csv')
#                                          Name  \
# 0                            #807 TUTTA BELLA
# 1                            #807 TUTTA BELLA
# 2                            #807 TUTTA BELLA
# 3                            #807 TUTTA BELLA
# 4                            #807 TUTTA BELLA
# ...                                       ...
# 264154  ZYLBERSCHTEIN'S DELICATESSEN & BAKERY
# 264155  ZYLBERSCHTEIN'S DELICATESSEN & BAKERY
# 264156  ZYLBERSCHTEIN'S DELICATESSEN & BAKERY
# 264157  ZYLBERSCHTEIN'S DELICATESSEN & BAKERY
# 264158  ZYLBERSCHTEIN'S DELICATESSEN & BAKERY
#
#                            Program Identifier Inspection Date  \
# 0                            #807 TUTTA BELLA      02/29/2024
# ...

# %%
pd.read_csv('data/Seattle_Police_PDRs_20240704.csv')
# Out:
#          Assigned Staff  Completed/Closed             Create Date  Days Open  \
# 0                 PDO 9              True  01/19/2016 08:29:00 AM   2.083333
# 1                PDO 24              True  01/06/2016 09:59:00 AM   6.083333
# 2                PDO 24              True  02/29/2016 10:46:00 AM   0.041666
# 3                PDO 11              True  03/09/2016 02:01:00 PM   1.083333
# 4                PDO 24              True  03/09/2016 02:17:00 PM   0.833333
# ...                 ...               ...                     ...        ...
# 37947  *SPD-Intake *PDU             False  02/05/2021 03:07:00 PM   0.083333
# 37948  *SPD-Intake *PDU             False  02/05/2021 03:12:00 PM   0.083333
# 37949  *SPD-Intake *PDU             False  02/05/2021 03:15:00 PM   0.083333
# 37950  *SPD-Intake *PDU             False  02/05/2021 04:13:00 PM   0.041666
# 37951  *SPD-Intake *PDU             False  02/05/2021 04:36:00 PM   0.041666
#
#              Request Status  \
# ...

# %%
mcdo = pd.read_csv('data/McDonalds.csv')

# %%
mcdo
# Out:
#                                  name storeid  country          subdivision  \
# 0                          McDonald's  nodata  Andorra     Andorra la Vella
# 1         McDonald's - Pas de la Casa  nodata  Andorra               Encamp
# 2          McDonald's - Av. Tarragona  nodata  Andorra     Andorra la Vella
# 3                 McDonald's - Epizen  nodata  Andorra  Sant Julià de Lòria
# 4      McDonald's Andorra - Meritxell  nodata  Andorra     Andorra la Vella
# ...                               ...     ...      ...                  ...
# 39190           McDonald's Nguyễn Huệ  nodata  Vietnam     Ho Chi Minh City
# 39191            McDonald's Vivo City  nodata  Vietnam     Ho Chi Minh City
# 39192      McDonald’s Satra Phạm Hùng  nodata  Vietnam     Ho Chi Minh City
# 39193            McDonald's Giga Mall  nodata  Vietnam     Ho Chi Minh City
# 39194        McDonald’s Saigon Centre  nodata  Vietnam     Ho Chi Minh City
#
# ...

# %%
mcdo[mcdo['city'] == 'Seattle']
# Out:
#                                    name storeid        country subdivision  \
# 32443                2147 Northgate Way    6443  United States          WA
# 32476     9610 Des Moines Memorial Dr S   13369  United States          WA
# 32484                9304 Rainier Ave S    4891  United States          WA
# 32501      Seattle-Tacoma Airport - SEA   35850  United States          WA
# 32506                 2580 Sw Barton St   15338  United States          WA
# 32525                  5146 25th Ave Ne    1697  United States          WA
# 32565            20227 Ballinger Way Ne   10163  United States          WA
# 32574  6305 Martin Luther King Jr Way S   13366  United States          WA
# 32579                    2401 4th Ave S   10755  United States          WA
# 32580            6546 California Ave Sw    1364  United States          WA
# 32581                      1530 3rd Ave    4308  United States          WA
# ...

# %%
import requests

url = "https://vanitysoft-boundaries-io-v1.p.rapidapi.com/rest/v1/public/boundary/zipcode"

querystring = {"city":"Seattle"}

headers = {
	"x-rapidapi-key": "fec571117amshe8bc07b67dd0a44p1d445djsn00cdcce7c9da",
	"x-rapidapi-host": "vanitysoft-boundaries-io-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'zipCode': '98132', 'country': 'US', 'city': 'Seattle', 'county': 'King', 'state': 'WA'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-122.28999882370499, 47.46004248096783], [-122.29004645963958, 47.460029696109586], [-122.29005788795621, 47.45997904657975], [-122.28999966563234, 47.45995567316208], [-122.28997032219382, 47.459960908357125], [-122.28996910047556, 47.459961367597806], [-122.28994641837771, 47.459976113963414], [-122.28993669810681, 47.45999948316345], [-122.28994045203999, 47.46001371697213], [-122.289943159337, 47.46001806902402], [-122.28995910526567, 47.46003204155915], [-122.28997883141665, 47.4600398559835], [-122.28999882370499, 47.46004248096783]]]}}, {'type': 'Feature', 'properties': {'zipCode': '98168', 'country': 'US', 'city': 'Seattle', 'county': 'King', 'state': 'WA'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-122.335293, 47.503121], [-122.333654, 47.503154], [-12
# ...

# %%
zipcode = response.json()

# %%
zipcode_df = pd.json_normalize(zipcode,
                                  sep="_",
                                  record_path="features",
                                  #meta=["status","timestamp"],
                                  #record_prefix="data_"
                                  )
# Print 
print(zipcode_df)
# Out:
#        type properties_zipCode properties_country properties_city  \
# 0   Feature              98132                 US         Seattle
# 1   Feature              98168                 US         Seattle
# 2   Feature              98158                 US         Seattle
# 3   Feature              98106                 US         Seattle
# 4   Feature              98177                 US         Seattle
# ..      ...                ...                ...             ...
# 58  Feature              98116                 US         Seattle
# 59  Feature              98121                 US         Seattle
# 60  Feature              98125                 US         Seattle
# 61  Feature              98119                 US         Seattle
# 62  Feature              98161                 US         Seattle
#
#    properties_county properties_state geometry_type  \
# 0               King               WA       Polygon
# 1               King               WA       Polygon
# ...

# %%
zipcode_df
# Out:
#        type properties_zipCode properties_country properties_city  \
# 0   Feature              98132                 US         Seattle
# 1   Feature              98168                 US         Seattle
# 2   Feature              98158                 US         Seattle
# 3   Feature              98106                 US         Seattle
# 4   Feature              98177                 US         Seattle
# ..      ...                ...                ...             ...
# 58  Feature              98116                 US         Seattle
# 59  Feature              98121                 US         Seattle
# 60  Feature              98125                 US         Seattle
# 61  Feature              98119                 US         Seattle
# 62  Feature              98161                 US         Seattle
#
#    properties_county properties_state geometry_type  \
# 0               King               WA       Polygon
# 1               King               WA       Polygon
# ...

# %%
import requests

url = "https://vanitysoft-boundaries-io-v1.p.rapidapi.com/reaperfire/rest/v1/public/boundary/neighborhood"

querystring = {"city":"Seattle"}

headers = {
	"x-rapidapi-key": "fec571117amshe8bc07b67dd0a44p1d445djsn00cdcce7c9da",
	"x-rapidapi-host": "vanitysoft-boundaries-io-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'city': 'Seattle', 'county': 'King', 'name': 'Westlake', 'state': 'WA'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-122.347316967338, 47.6440471597909], [-122.34727427308, 47.6435775229596], [-122.347188884565, 47.64307942329], [-122.347075033212, 47.6426667121352], [-122.346719247734, 47.6415139671856], [-122.346363462256, 47.6405604621037], [-122.345737279814, 47.6393507914775], [-122.344285675063, 47.6373726242187], [-122.344015278099, 47.6369883759021], [-122.343773343974, 47.6366183590047], [-122.343559872687, 47.6362341106881], [-122.343460252753, 47.6359494823056], [-122.343431789915, 47.6324058589418], [-122.343588335525, 47.6280083504299], [-122.34371779866, 47.6245701922007], [-122.343737305974, 47.623741135239], [-122.342627443699, 47.6244863188192], [-122.34178712547, 47.6249064779333], [-122.340076477648, 47.6253566484129], [-122.339146125324, 47.6255667279698], [-122.337825625251, 47.6
# ...

# %%
neighborhood = response.json()

# %%
neighborhood_df = pd.json_normalize(neighborhood,
                                  sep="_",
                                  record_path="features",
                                  #meta=["status","timestamp"],
                                  #record_prefix="data_"
                                  )
# Print 
print(neighborhood_df)
# Out:
#        type properties_city properties_county properties_name  \
# 0   Feature         Seattle              King        Westlake
# 1   Feature         Seattle              King      Sand Point
# 2   Feature         Seattle              King      South Park
# 3   Feature         Seattle              King       Pinehurst
# 4   Feature         Seattle              King        Brighton
# ..      ...             ...               ...             ...
# 75  Feature         Seattle              King        Belltown
# 76  Feature         Seattle              King    West Seattle
# 77  Feature         Seattle              King          Bryant
# 78  Feature         Seattle              King            Alki
# 79  Feature         Seattle              King      Georgetown
#
#    properties_state geometry_type  \
# 0                WA       Polygon
# 1                WA       Polygon
# 2                WA       Polygon
# 3                WA       Polygon
# 4                WA       Polygon
# ...

# %%
neighborhood_df[neighborhood_df['properties_name'] == 'Pinehurst']
# Out:
#       type properties_city properties_county properties_name properties_state  \
# 3  Feature         Seattle              King       Pinehurst               WA
#
#   geometry_type                               geometry_coordinates
# 3       Polygon  [[[-122.32835521708, 47.7122682676493], [-122....

# %%
neighborhood_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   type                      80 non-null     object
#  1   properties_city           80 non-null     object
#  2   properties_county         80 non-null     object
#  3   properties_name           80 non-null     object
#  4   properties_state          80 non-null     object
#  5   geometry_type             80 non-null     object
#  6   geometry_coordinates      80 non-null     object
#  7   geometry_coordinates_str  80 non-null     object
# dtypes: object(8)
# memory usage: 5.1+ KB

# %%
zipcode_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   type                      63 non-null     object
#  1   properties_zipCode        63 non-null     object
#  2   properties_country        63 non-null     object
#  3   properties_city           63 non-null     object
#  4   properties_county         63 non-null     object
#  5   properties_state          63 non-null     object
#  6   geometry_type             63 non-null     object
#  7   geometry_coordinates      63 non-null     object
#  8   geometry_coordinates_str  63 non-null     object
# dtypes: object(9)
# memory usage: 4.6+ KB

# %%
import geopandas as gpd

# %%
# Convert geometry coordinates to strings
zipcode_df['geometry_coordinates_str'] = zipcode_df['geometry_coordinates'].apply(str)
neighborhood_df['geometry_coordinates_str'] = neighborhood_df['geometry_coordinates'].apply(str)

# %%
pd.merge(zipcode_df, neighborhood_df, on='geometry_type', how='inner')
# Out:
#        type_x properties_zipCode properties_country properties_city_x  \
# 0     Feature              98132                 US           Seattle
# 1     Feature              98132                 US           Seattle
# 2     Feature              98132                 US           Seattle
# 3     Feature              98132                 US           Seattle
# 4     Feature              98132                 US           Seattle
# ...       ...                ...                ...               ...
# 4955  Feature              98161                 US           Seattle
# 4956  Feature              98161                 US           Seattle
# 4957  Feature              98161                 US           Seattle
# 4958  Feature              98161                 US           Seattle
# 4959  Feature              98161                 US           Seattle
#
#      properties_county_x properties_state_x geometry_type  \
# 0                   King                 WA       Polygon
# ...

# %%
pd.read_csv('data/DP04_5YALL_3840298254942809598.csv')
# Out:
#       OBJECTID        GEOID  Total Housing Units  Occupied Housing Units  \
# 0          989  53033024100                 1885                    1731
# 1          990  53033024200                 1113                    1054
# 2          991  53033024500                 1821                    1716
# 3          992  53033024601                 1751                    1635
# 4          993  53033024602                 1240                    1231
# ...        ...          ...                  ...                     ...
# 2271      5537  53033032703                  874                     779
# 2272      5538  53033032704                 2922                    2869
# 2273      5539  53033032705                 1339                    1339
# 2274      5540  53033032706                 1323                     983
# 2275      5541  53033032800                 1585                    1081
#
#       Vacant Housing Units  Homeowner Vacancy Rate  Rental Vacancy Rate  \
# ...

# %%
pd.read_csv('data/Unemployment_Rate_Chart.csv')
# Out:
#          Year  Seattle  King County   Washington State  United States
# 0    Jan 2005      4.2           4.9               6.4            5.7
# 1    Feb 2005      4.6           5.3               6.6            5.8
# 2    Mar 2005      4.5           4.9               6.0            5.4
# 3    Apr 2005      3.8           4.3               5.5            4.9
# 4    May 2005      4.3           4.8               5.4            4.9
# ..        ...      ...           ...               ...            ...
# 118  Nov 2014      4.1           4.5               6.2            5.5
# 119  Dec 2014      3.8           4.2               6.3            5.4
# 120  Jan 2015      4.3           4.8               7.0            6.1
# 121  Feb 2015      4.3           4.8               6.8            5.8
# 122  Mar 2015      3.7           4.1               5.7            5.6
#
# [123 rows x 5 columns]

# %%
census = pd.read_csv('data/2020_Census_Tracts_Seattle_-7486928068189135549.csv')

# %%
census
# Out:
#      OBJECTID      GEOID20  Gross Acres  Land Acres  Water Acres  \
# 0           1  53033000402   444.493643  444.527261     0.000000
# 1           2  53033000403   180.930716  165.408389    15.535762
# 2           3  53033000700   319.838996  319.862596     0.000000
# 3           4  53033003302   154.942826  154.952619     0.000000
# 4           5  53033003601   166.571397  166.583375     0.000000
# ..        ...          ...          ...         ...          ...
# 172       367  53033008101    68.690415   66.798515    68.613998
# 173       368  53033010401   402.739919  402.750637     0.000000
# 174       369  53033011401   304.713408  304.719237     0.000000
# 175       370  53033011700   868.762098  868.775078     0.000000
# 176       371  53033011901   415.718564  415.723669     0.000000
#
#               Tract Name  Tract  Tract Label Urban Village Demographic Area  \
# 0      Census Tract 4.02    402         4.02            Bitter Lake Village
# ...

# %%
GEOID_name = census[['GEOID20','Urban Village Demographic Area']]
GEOID_name
# Out:
#          GEOID20 Urban Village Demographic Area
# 0    53033000402            Bitter Lake Village
# 1    53033000403            Bitter Lake Village
# 2    53033000700                      Lake City
# 3    53033003302                        Ballard
# 4    53033003601         Green Lake - Roosevelt
# ..           ...                            ...
# 172  53033008101                    Center City
# 173  53033010401                        Othello
# 174  53033011401         Westwood-Highland Park
# 175  53033011700                  Rainier Beach
# 176  53033011901            Outside - Southeast
#
# [177 rows x 2 columns]

# %%
housing = pd.read_csv('data/Neighborhood_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')

# %%
housing.transpose()
# Out:
#                     0              1                2                3      \
# RegionID           112345         192689           270958           270957
# SizeRank                0              1                2                3
# RegionName       Maryvale       Paradise  Upper West Side  Upper East Side
# RegionType   neighborhood   neighborhood     neighborhood     neighborhood
# StateName              AZ             NV               NY               NY
# ...                   ...            ...              ...              ...
# 2024-01-31  340185.954642  384915.736835   1227011.263077   1194616.945725
# 2024-02-29  341173.194065  386779.973241   1220837.518658   1188670.899573
# 2024-03-31  342669.851589  388646.284641   1215409.416679   1184782.812331
# 2024-04-30  344519.394807  391119.657883   1213069.493921   1182829.997627
# 2024-05-31  345964.317041   393802.43252   1210757.413529   1179745.775707
#
#                         4              5              6      \
# ...

# %%
housing_seattle = housing[housing['City'] == 'Seattle']
housing_seattle
# Out:
#        RegionID  SizeRank           RegionName    RegionType StateName State  \
# 293      250206       305         Capitol Hill  neighborhood        WA    WA
# 386      272001       404  University District  neighborhood        WA    WA
# 712      271990       743             Magnolia  neighborhood        WA    WA
# 796      250788       834            Greenwood  neighborhood        WA    WA
# 831      252248       870          Wallingford  neighborhood        WA    WA
# ...         ...       ...                  ...           ...       ...   ...
# 12137    250149     13666            Broadmoor  neighborhood        WA    WA
# 12153    271804     13684             Atlantic  neighborhood        WA    WA
# 13311    344016     15147        Jackson Place  neighborhood        WA    WA
# 16320    344011     18964       Denny - Blaine  neighborhood        WA    WA
# 17375    271963     20296       Pioneer Square  neighborhood        WA    WA
#
# ...

# %%
pd.read_csv('data/DP04_5YALL_3840298254942809598.csv')
# Out:
#       OBJECTID        GEOID  Total Housing Units  Occupied Housing Units  \
# 0          989  53033024100                 1885                    1731
# 1          990  53033024200                 1113                    1054
# 2          991  53033024500                 1821                    1716
# 3          992  53033024601                 1751                    1635
# 4          993  53033024602                 1240                    1231
# ...        ...          ...                  ...                     ...
# 2271      5537  53033032703                  874                     779
# 2272      5538  53033032704                 2922                    2869
# 2273      5539  53033032705                 1339                    1339
# 2274      5540  53033032706                 1323                     983
# 2275      5541  53033032800                 1585                    1081
#
#       Vacant Housing Units  Homeowner Vacancy Rate  Rental Vacancy Rate  \
# ...

# %%
crime.isnull().sum()
# Out:
# Report Number                  0
# Offense ID                     0
# Offense Start DateTime      1810
# Offense End DateTime      480995
# Report DateTime                0
# Group A B                      0
# Crime Against Category         0
# Offense Parent Group           0
# Offense                        0
# Offense Code                   0
# Precinct                       7
# Sector                         7
# Beat                           7
# MCPP                          27
# 100 Block Address          50283
# Longitude                      0
# Latitude                       0
# dtype: int64
