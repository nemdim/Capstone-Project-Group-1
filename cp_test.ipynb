# %%
import pandas as pd
import chardet

# %%
hotel_data = pd.read_csv('data/hotels.csv',  encoding='ISO-8859-1')
countries_data = pd.read_csv('data/countries.csv') 
asean_data = pd.read_csv('data/pivot.csv', header = 1) 
gdp_data = pd.read_csv('data/gdp.csv')

# %%
gdp_data.columns = gdp_data.columns.str.lower().str.strip().str.replace(' ','_')

# %%
gdp_data = gdp_data[gdp_data['country_name'].isin(['Brunei', 'Cambodia', 'Indonesia', 'Laos', 'Malaysia','Myanmar', 'Philippines', 'Singapore', 'Thailand', 'Vietnam'])]

# %%
gdp_data.reset_index
# Out:
#     country_name country_code     indicator_name  indicator_code  \
# 106    Indonesia          IDN  GDP (current US$)  NY.GDP.MKTP.CD
# 123     Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD
# 160      Myanmar          MMR  GDP (current US$)  NY.GDP.MKTP.CD
# 169     Malaysia          MYS  GDP (current US$)  NY.GDP.MKTP.CD
# 187  Philippines          PHL  GDP (current US$)  NY.GDP.MKTP.CD
# 208    Singapore          SGP  GDP (current US$)  NY.GDP.MKTP.CD
# 233     Thailand          THA  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 106           NaN           NaN           NaN           NaN           NaN
# 123           NaN           NaN           NaN           NaN           NaN
# 160  5.450984e+08  6.055816e+08  6.345289e+08  5.989984e+08  4.114199e+08
# 169  1.916229e+09  1.901856e+09  2.001490e+09  2.510110e+09  2.674424e+09
# 187  7.515894e+09  8.171194e+09  4.954593e+09  5.505023e+09  5.953756e+09
# ...

# %%
employment_data = pd.read_excel('data/employment.xlsx')

# %%
hotel_data.columns
# Out:
# Index(['countyCode', ' countyName', ' cityCode', ' cityName', ' HotelCode',
#        ' HotelName', ' HotelRating', ' Address', ' Attractions',
#        ' Description', ' FaxNumber', ' HotelFacilities', ' Map',
#        ' PhoneNumber', ' PinCode', ' HotelWebsiteUrl'],
#       dtype='object')

# %%
asean_hotel = hotel_data[hotel_data[' countyName'].isin(['Brunei', 'Cambodia', 'Indonesia', 'Laos', 'Malaysia','Myanmar', 'Philippines', 'Singapore', 'Thailand', 'Vietnam'])]
#'hotel_data.info()

# %%
asean_hotel
# Out:
#         countyCode  countyName   cityCode   cityName   HotelCode  \
# 117112          KH    Cambodia     102197    Banlung     1166458
# 117113          KH    Cambodia     102197    Banlung     1425637
# 117114          KH    Cambodia     102197    Banlung     1573709
# 117115          KH    Cambodia     102197    Banlung     1573997
# 117116          KH    Cambodia     102197    Banlung     1574033
# ...            ...         ...        ...        ...         ...
# 1009272         VN     Vietnam     150331  Vinh Phuc     1438775
# 1009273         VN     Vietnam     142386   Vung Tau     1027329
# 1009274         VN     Vietnam     107998  Xuyen Moc     1027329
# 1009275         VN     Vietnam     107998  Xuyen Moc     1284073
# 1009276         VN     Vietnam     107998  Xuyen Moc     1369581
#
#                                    HotelName  HotelRating  \
# 117112                   Terres Rouges Lodge    ThreeStar
# 117113                              SN Hotel    ThreeStar
# ...

# %%
countries_data
# Out:
#      Rank   ID                   Country      Continent  Population  \
# 0       1  840             United States  North America   339996.56
# 1       2  156                     China           Asia  1425671.35
# 2       3  392                     Japan           Asia   123294.51
# 3       4  276                   Germany         Europe    83294.63
# 4       5  356                     India           Asia  1428627.66
# ..    ...  ...                       ...            ...         ...
# 207   208  729                     Sudan         Africa    48109.01
# 208   209  760                     Syria           Asia    23227.01
# 209   210  788                   Tunisia         Africa    12458.22
# 210   211  796  Turks and Caicos Islands  North America       46.06
# 211   212  804                   Ukraine         Europe    36744.63
#
#           IMF_GDP        UN_GDP  GDP_per_capita
# 0    2.669515e+13  1.862448e+13        78515.94
# 1    2.186548e+13  1.121828e+13        15336.97
# ...

# %% [markdown]
# **asean_data set here**

# %%
asean_data
# Out:
#    Destination Country         Origin Country        1995        1996  \
# 0    Brunei Darussalam  Total Country (World)         NaN         NaN
# 1             Cambodia  Total Country (World)     219 680     260 489
# 2            Indonesia  Total Country (World)   4 324 229   5 034 472
# 3              Lao PDR  Total Country (World)     346 460     403 000
# 4             Malaysia  Total Country (World)   7 468 749   7 138 452
# 5              Myanmar  Total Country (World)     109 773     163 486
# 6          Philippines  Total Country (World)   1 760 063   2 049 367
# 7            Singapore  Total Country (World)   7 137 255   7 292 521
# 8             Thailand  Total Country (World)   6 951 566   7 244 400
# 9             Viet Nam  Total Country (World)   1 351 296   1 607 155
# 10               ASEAN  Total Country (World)  29 669 071  31 193 342
#
#           1997        1998        1999        2000        2001        2002  \
# ...

# %%
asean_data
# Out:
#    Destination Country         Origin Country        1995        1996  \
# 0    Brunei Darussalam  Total Country (World)         NaN         NaN
# 1             Cambodia  Total Country (World)     219 680     260 489
# 2            Indonesia  Total Country (World)   4 324 229   5 034 472
# 3              Lao PDR  Total Country (World)     346 460     403 000
# 4             Malaysia  Total Country (World)   7 468 749   7 138 452
# 5              Myanmar  Total Country (World)     109 773     163 486
# 6          Philippines  Total Country (World)   1 760 063   2 049 367
# 7            Singapore  Total Country (World)   7 137 255   7 292 521
# 8             Thailand  Total Country (World)   6 951 566   7 244 400
# 9             Viet Nam  Total Country (World)   1 351 296   1 607 155
# 10               ASEAN  Total Country (World)  29 669 071  31 193 342
#
#           1997        1998        1999        2000        2001        2002  \
# ...

# %%
asean_data.loc[:, '1995':'2022'] = asean_data.loc[:, '1995':'2022'].replace(' ', '', regex=True)

# %%
asean_data
# Out:
#    Destination Country         Origin Country      1995      1996      1997  \
# 0    Brunei Darussalam  Total Country (World)       NaN       NaN    643215
# 1             Cambodia  Total Country (World)    219680    260489    218843
# 2            Indonesia  Total Country (World)   4324229   5034472   5185243
# 3              Lao PDR  Total Country (World)    346460    403000    463200
# 4             Malaysia  Total Country (World)   7468749   7138452   6210921
# 5              Myanmar  Total Country (World)    109773    163486    188692
# 6          Philippines  Total Country (World)   1760063   2049367   2222523
# 7            Singapore  Total Country (World)   7137255   7292521   7197963
# 8             Thailand  Total Country (World)   6951566   7244400   7293957
# 9             Viet Nam  Total Country (World)   1351296   1607155   1715637
# 10               ASEAN  Total Country (World)  29669071  31193342  31340194
#
# ...

# %%
asean_data.drop(columns=['Origin Country'], inplace=True)

# %%
asean_data
# Out:
#    Destination Country      1995      1996      1997      1998      1999  \
# 0    Brunei Darussalam       NaN       NaN    643215    964080    954907
# 1             Cambodia    219680    260489    218843    175910    262907
# 2            Indonesia   4324229   5034472   5185243   4606416   4728080
# 3              Lao PDR    346460    403000    463200    500200    624432
# 4             Malaysia   7468749   7138452   6210921   5550748   7931149
# 5              Myanmar    109773    163486    188692    197726    195422
# 6          Philippines   1760063   2049367   2222523   2149357   1971224
# 7            Singapore   7137255   7292521   7197963   6242152   6967260
# 8             Thailand   6951566   7244400   7293957   7842761   8798085
# 9             Viet Nam   1351296   1607155   1715637   1503654   1781754
# 10               ASEAN  29669071  31193342  31340194  29733004  34215220
#
#         2000      2001      2002      2003  ...       2014       2015  \
# ...

# %%
asean_data.loc[:, 'Destination Country'] = asean_data.loc[:, 'Destination Country'].replace(' ', '_', regex=True)

# %%
asean_data
# Out:
#    Destination Country      1995      1996      1997      1998      1999  \
# 0    Brunei_Darussalam       NaN       NaN    643215    964080    954907
# 1             Cambodia    219680    260489    218843    175910    262907
# 2            Indonesia   4324229   5034472   5185243   4606416   4728080
# 3              Lao_PDR    346460    403000    463200    500200    624432
# 4             Malaysia   7468749   7138452   6210921   5550748   7931149
# 5              Myanmar    109773    163486    188692    197726    195422
# 6          Philippines   1760063   2049367   2222523   2149357   1971224
# 7            Singapore   7137255   7292521   7197963   6242152   6967260
# 8             Thailand   6951566   7244400   7293957   7842761   8798085
# 9             Viet_Nam   1351296   1607155   1715637   1503654   1781754
# 10               ASEAN  29669071  31193342  31340194  29733004  34215220
#
#         2000      2001      2002      2003  ...       2014       2015  \
# ...

# %%
asean_data.columns = asean_data.columns.str.lower().str.replace(' ', '_')

# %%
asean_data['destination_country']=asean_data['destination_country'].str.lower()

# %%
asean_data
# Out:
#    destination_country      1995      1996      1997      1998      1999  \
# 0    brunei_darussalam       NaN       NaN    643215    964080    954907
# 1             cambodia    219680    260489    218843    175910    262907
# 2            indonesia   4324229   5034472   5185243   4606416   4728080
# 3              lao_pdr    346460    403000    463200    500200    624432
# 4             malaysia   7468749   7138452   6210921   5550748   7931149
# 5              myanmar    109773    163486    188692    197726    195422
# 6          philippines   1760063   2049367   2222523   2149357   1971224
# 7            singapore   7137255   7292521   7197963   6242152   6967260
# 8             thailand   6951566   7244400   7293957   7842761   8798085
# 9             viet_nam   1351296   1607155   1715637   1503654   1781754
# 10               asean  29669071  31193342  31340194  29733004  34215220
#
#         2000      2001      2002      2003  ...       2014       2015  \
# ...

# %%
asean_data['visitor_avg']= asean_data.mean(numeric_only=True, axis=1)

# %%
#asean_data['visitor_avg'] = asean_data['visitor_avg'].astype(int)

# %%
asean_data.set_index('destination_country')
# Out:
#                          1995      1996      1997      1998      1999  \
# destination_country
# brunei_darussalam         NaN       NaN    643215    964080    954907
# cambodia               219680    260489    218843    175910    262907
# indonesia             4324229   5034472   5185243   4606416   4728080
# lao_pdr                346460    403000    463200    500200    624432
# malaysia              7468749   7138452   6210921   5550748   7931149
# myanmar                109773    163486    188692    197726    195422
# philippines           1760063   2049367   2222523   2149357   1971224
# singapore             7137255   7292521   7197963   6242152   6967260
# thailand              6951566   7244400   7293957   7842761   8798085
# viet_nam              1351296   1607155   1715637   1503654   1781754
# asean                29669071  31193342  31340194  29733004  34215220
#
#                          2000      2001      2002      2003      2004  ...  \
# ...

# %%
asean_data.loc[['destination_country'], ['1995', '2022']]x^
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 asean_data.loc[['destination_country'], ['1995', '2022']]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/indexing.py:1337, in _LocIndexer._getitem_tuple(self, tup)
#    1335 # ugly hack for GH #836
#    1336 if self._multi_take_opportunity(tup):
# -> 1337     return self._multi_take(tup)
# ...
